# %%
# 🍔 FoodSense: Data Cleaning & ETL Process

#This notebook focuses on loading, understanding, and cleaning the food ordering behavior dataset as part of the ETL process.

# %%
import pandas as pd

df = pd.read_csv(r"C:\Users\anshi\Desktop\FoodSENSE;Costomer_behaviour_intelligence_for_food_delivery\food_ordering_behavior_dataset.csv")
df.head()
# Out:
#    order_id  user_id  age        city order_time day_type       cuisine  \
# 0         1     2698   35        pune    evening  weekend       chinese
# 1         2     3237   44      mumbai      night  weekend  south indian
# 2         3     3626   31       delhi    morning  weekend       biryani
# 3         4     3176   23       delhi    evening  weekend       biryani
# 4         5     4824   26  chandigarh    morning  weekday       chinese
#
#    meal_type restaurant_type  order_value discount_applied  delivery_fee  \
# 0     dinner         premium          971              yes            90
# 1     dinner          budget          442               no            26
# 2  breakfast       mid-range          739              yes            85
# 3     snacks       mid-range          466               no            44
# 4      lunch         premium          927              yes            58
#
#    time_taken_to_order  rating_given is_repeat_order         mood  \
# ...

# %%
## 🔍 Data Understanding

'''In this step, the structure and quality of the dataset are explored to understand:
- Number of rows and columns
- Data types
- Statistical summary
- Missing values'''
# Out:
# 'In this step, the structure and quality of the dataset are explored to understand:\n- Number of rows and columns\n- Data types\n- Statistical summary\n- Missing values'

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50000 entries, 0 to 49999
# Data columns (total 19 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   order_id             50000 non-null  int64
#  1   user_id              50000 non-null  int64
#  2   age                  50000 non-null  int64
#  3   city                 50000 non-null  object
#  4   order_time           50000 non-null  object
#  5   day_type             50000 non-null  object
#  6   cuisine              50000 non-null  object
#  7   meal_type            50000 non-null  object
#  8   restaurant_type      50000 non-null  object
#  9   order_value          50000 non-null  int64
#  10  discount_applied     50000 non-null  object
#  11  delivery_fee         50000 non-null  int64
#  12  time_taken_to_order  50000 non-null  int64
#  13  rating_given         50000 non-null  int64
#  14  is_repeat_order      50000 non-null  object
# ...

# %%
## 📊 Statistical Summary

'''This step provides statistical insights into numerical columns such as:
- Mean
- Minimum and maximum values
- Distribution of data

It helps in understanding the overall behavior of numerical features.'''
df.describe()
# Out:
#            order_id       user_id           age   order_value  delivery_fee  \
# count  50000.000000  50000.000000  50000.000000  50000.000000  50000.000000
# mean   25000.500000   3005.466160     30.975420    547.731100     59.642720
# std    14433.901067   1152.286323      7.804962    259.685968     23.043375
# min        1.000000   1000.000000     18.000000    100.000000     20.000000
# 25%    12500.750000   2013.000000     24.000000    323.000000     40.000000
# 50%    25000.500000   3004.000000     31.000000    547.000000     60.000000
# 75%    37500.250000   4002.000000     38.000000    772.000000     80.000000
# max    50000.000000   4999.000000     44.000000    999.000000     99.000000
#
#        time_taken_to_order  rating_given
# count         50000.000000  50000.000000
# mean              7.496720      2.994420
# std               4.031059      1.413361
# min               1.000000      1.000000
# 25%               4.000000      2.000000
# ...

# %%
## 🏷️ Column Inspection

#In this step, all column names are reviewed to understand the available features in the dataset.

#This helps in planning further analysis and identifying important business-related variables.

# %%
df.columns
# Out:
# Index(['order_id', 'user_id', 'age', 'city', 'order_time', 'day_type',
#        'cuisine', 'meal_type', 'restaurant_type', 'order_value',
#        'discount_applied', 'delivery_fee', 'time_taken_to_order',
#        'rating_given', 'is_repeat_order', 'mood', 'hunger_level', 'company',
#        'rainy_weather'],
#       dtype='object')

# %%
## ❗ Missing Value Analysis

'''This step checks whether the dataset contains any missing or null values.

Handling missing values is important to maintain data quality and ensure accurate analysis.'''
# Out:
# 'This step checks whether the dataset contains any missing or null values.\n\nHandling missing values is important to maintain data quality and ensure accurate analysis.'

# %%
df.isnull().sum()
# Out:
# order_id               0
# user_id                0
# age                    0
# city                   0
# order_time             0
# day_type               0
# cuisine                0
# meal_type              0
# restaurant_type        0
# order_value            0
# discount_applied       0
# delivery_fee           0
# time_taken_to_order    0
# rating_given           0
# is_repeat_order        0
# mood                   0
# hunger_level           0
# company                0
# rainy_weather          0
# dtype: int64

# %%
## 🔁 Duplicate Record Check

'''This step checks whether duplicate records exist in the dataset.

Duplicate rows can negatively impact analysis and lead to misleading insights.'''
# Out:
# 'This step checks whether duplicate records exist in the dataset.\n\nDuplicate rows can negatively impact analysis and lead to misleading insights.'

# %%
df.duplicated().sum()
# Out:
# 0

# %%
## 🧹 Text Standardization

'''In this step, categorical text values are standardized by converting them to lowercase.

This helps maintain consistency in the dataset and prevents incorrect grouping during analysis.'''
# Out:
# 'In this step, categorical text values are standardized by converting them to lowercase.\n\nThis helps maintain consistency in the dataset and prevents incorrect grouping during analysis.'

# %%
df = df.apply(lambda x: x.str.lower() if x.dtype == "object" else x)

df.head()
# Out:
#    order_id  user_id  age        city order_time day_type       cuisine  \
# 0         1     2698   35        pune    evening  weekend       chinese
# 1         2     3237   44      mumbai      night  weekend  south indian
# 2         3     3626   31       delhi    morning  weekend       biryani
# 3         4     3176   23       delhi    evening  weekend       biryani
# 4         5     4824   26  chandigarh    morning  weekday       chinese
#
#    meal_type restaurant_type  order_value discount_applied  delivery_fee  \
# 0     dinner         premium          971              yes            90
# 1     dinner          budget          442               no            26
# 2  breakfast       mid-range          739              yes            85
# 3     snacks       mid-range          466               no            44
# 4      lunch         premium          927              yes            58
#
#    time_taken_to_order  rating_given is_repeat_order         mood  \
# ...

# %%
## 💾 Saving Cleaned Dataset

'''The cleaned dataset is saved for further analysis and visualization.

This cleaned data will be used in:
- Exploratory Data Analysis (EDA)
- SQL Analysis
- Power BI Dashboard'''
# Out:
# 'The cleaned dataset is saved for further analysis and visualization.\n\nThis cleaned data will be used in:\n- Exploratory Data Analysis (EDA)\n- SQL Analysis\n- Power BI Dashboard'

# %%
df.to_csv(r"C:\Users\anshi\Desktop\FoodSENSE;Costomer_behaviour_intelligence_for_food_delivery\cleaned_data.csv", index=False)
